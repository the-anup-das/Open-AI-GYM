# %% [markdown]
# Baseline Documentation [https://stable-baselines3.readthedocs.io/en/master/](https://stable-baselines3.readthedocs.io/en/master/)

# %% [markdown]
# ### 1. Import Dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in d:\program_installation\anaconda\lib\site-packages (1.6.0)
# Requirement already satisfied: matplotlib in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: cloudpickle in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: torch>=1.11 in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (1.12.0)
# Requirement already satisfied: numpy in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Requirement already satisfied: pandas in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: gym==0.21 in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: tensorboard>=2.2.0 in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (2.9.1)
# Requirement already satisfied: ale-py==0.7.4 in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: opencv-python in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: protobuf~=3.19.0 in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: pillow in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: psutil in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in d:\program_installation\anaconda\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: importlib-metadata>=4.10.0 in d:\program_installation\anaconda\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: importlib-resources in d:\program_installation\anaconda\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: tqdm in d:\program_installation\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: requests in d:\program_installation\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: click in c:\users\awesome\appdata\roaming\python\python39\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: AutoROM.accept-rom-license in d:\program_installation\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in d:\program_installation\anaconda\lib\site-packages (from importlib-metadata>=4.10.0->ale-py==0.7.4->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: absl-py>=0.4 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (61.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: wheel>=0.26 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.42.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\program_installation\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\program_installation\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\awesome\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\program_installation\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\program_installation\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\program_installation\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\program_installation\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\program_installation\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\program_installation\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program_installation\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\program_installation\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\program_installation\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: typing-extensions in c:\users\awesome\appdata\roaming\python\python39\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.1.1)
# Requirement already satisfied: colorama in c:\users\awesome\appdata\roaming\python\python39\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in d:\program_installation\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\program_installation\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\program_installation\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\awesome\appdata\roaming\python\python39\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\program_installation\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\program_installation\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in d:\program_installation\anaconda\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)

# %%
# !pip install pyglet
# Out:
# Requirement already satisfied: pyglet in d:\program_installation\anaconda\lib\site-packages (1.5.26)

# %% [markdown]
# ### 2. Load Environment

# %%
import os
import gym   # help us to build enviroment and work with preexisting enviroments
from stable_baselines3 import PPO   
from stable_baselines3.common.vec_env import DummyVecEnv #vectorize enviroments it allow to train a model multiple agent at a time
from stable_baselines3.common.evaluation import evaluate_policy # to test how our model is performing

# %% [markdown]
# **Box** - n dimensional tensor, range of values
# E.g. Box(0,1,shape=(3,3))
#
# **Discrete** - set of items
# E.g. Discrete(3)
#
# **Tuple** - tuple of other spaces e.g.Box or Discrete
# E.g. Tuple((Discrete(2), Box(0,100, shape = (1,))))
#
# **Dict** - dictionary of spaces e.g. Box or Discrete
# E.g. Dict({'height':Discrete(2), 'speed':Box (0,100, shape=(1,))})
#
# **MultiBinary** - one hot encoded binary values
# E.g. MultiBinary(4)
#
# **MultiDiscrete** - multiple discrete values
# E.g. MultiDiscrete([5,2,2])

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

# %%
environment_name
# Out:
# 'CartPole-v0'

# %%
episodes = 20
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print(f'Episode: {episode} score: {score}')
env.close()
# Out:
# Episode: 1 score: 33.0
# Episode: 2 score: 15.0
# Episode: 3 score: 12.0
# Episode: 4 score: 27.0
# Episode: 5 score: 18.0
# Episode: 6 score: 11.0
# Episode: 7 score: 18.0
# Episode: 8 score: 26.0
# Episode: 9 score: 12.0
# Episode: 10 score: 21.0
# Episode: 11 score: 22.0
# Episode: 12 score: 15.0
# Episode: 13 score: 22.0
# Episode: 14 score: 19.0
# Episode: 15 score: 48.0
# Episode: 16 score: 34.0
# Episode: 17 score: 22.0
# Episode: 18 score: 13.0
# Episode: 19 score: 10.0
# Episode: 20 score: 40.0

# %% [markdown]
# ## Understanding the environment
# [https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py]
#
#   ### Action Space
#     The action is a `ndarray` with shape `(1,)` which can take values `{0, 1}` indicating the direction
#      of the fixed force the cart is pushed with.
#     | Num | Action                 |
#     |-----|------------------------|
#     | 0   | Push cart to the left  |
#     | 1   | Push cart to the right |
#     **Note**: The velocity that is reduced or increased by the applied force is not fixed and it depends on the angle
#      the pole is pointing. The center of gravity of the pole varies the amount of energy needed to move the cart underneath it
#
#  ### Observation Space
#     The observation is a `ndarray` with shape `(4,)` with the values corresponding to the following positions and velocities:
#     | Num | Observation           | Min                 | Max               |
#     |-----|-----------------------|---------------------|-------------------|
#     | 0   | Cart Position         | -4.8                | 4.8               |
#     | 1   | Cart Velocity         | -Inf                | Inf               |
#     | 2   | Pole Angle            | ~ -0.418 rad (-24°) | ~ 0.418 rad (24°) |
#     | 3   | Pole Angular Velocity | -Inf                | Inf               |

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.observation_space.sample()
# Out:
# array([-4.6927400e+00, -2.8965313e+38, -6.6490263e-02, -2.9868164e+38],
#       dtype=float32)

# %% [markdown]
# ### 3. Train an RL Model

# %%
# create directories first
log_path = os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda:env])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %% [markdown]
# https://spinningup.openai.com/en/latest/spinningup/rl_intro.html

# %%
PPO??

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 266  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0082615465 |
# |    clip_fraction        | 0.0864       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.00191     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.9          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 46.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011134569 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 34.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007373777 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 54          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 5           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008724708 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 62.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009619617 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 61.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 7          |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00790997 |
# |    clip_fraction        | 0.054      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.568     |
# |    explained_variance   | 0.486      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.1       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00886   |
# |    value_loss           | 51.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 8           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008455966 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00626    |
# |    value_loss           | 28          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 9           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008647844 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.19        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 26.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 10          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008618845 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 38.1        |
# -----------------------------------------

# %% [markdown]
# ### 4. Save and Reload Model

# %%
PPO_Path = os.path.join('Training','Saved Models','PPO_Model_Cartpole')

# %%
model.save(PPO_Path)
# Out:
# D:\Program_Installation\anaconda\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'Training\Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %%
PPO_Path
# Out:
# 'Training\\Saved Models\\PPO_Model_Cartpole'

# %%
model = PPO.load(PPO_Path, env=env)

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 538  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [64], in <module>
# ----> 1 model.learn(total_timesteps=20000)
#
# File D:\Program_Installation\anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:310, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297 def learn(
#     298     self,
#     299     total_timesteps: int,
#    (...)
#     307     reset_num_timesteps: bool = True,
#     308 ) -> "PPO":
# --> 310     return super().learn(
#     311         total_timesteps=total_timesteps,
#     312         callback=callback,
#     313         log_interval=log_interval,
#     314         eval_env=eval_env,
#     315         eval_freq=eval_freq,
#     316         n_eval_episodes=n_eval_episodes,
#     317         tb_log_name=tb_log_name,
#     318         eval_log_path=eval_log_path,
#     319         reset_num_timesteps=reset_num_timesteps,
#     320     )
#
# File D:\Program_Installation\anaconda\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:267, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     264         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     265         self.logger.dump(step=self.num_timesteps)
# --> 267     self.train()
#     269 callback.on_training_end()
#     271 return self
#
# File D:\Program_Installation\anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:273, in PPO.train(self)
#     271     # Clip grad norm
#     272     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 273     self.policy.optimizer.step()
#     275 if not continue_training:
#     276     break
#
# File D:\Program_Installation\anaconda\lib\site-packages\torch\optim\optimizer.py:109, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     107 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     108 with torch.autograd.profiler.record_function(profile_name):
# --> 109     return func(*args, **kwargs)
#
# File D:\Program_Installation\anaconda\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File D:\Program_Installation\anaconda\lib\site-packages\torch\optim\adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File D:\Program_Installation\anaconda\lib\site-packages\torch\optim\adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File D:\Program_Installation\anaconda\lib\site-packages\torch\optim\adam.py:255, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     253     assert param.is_cuda and step_t.is_cuda, "If capturable=True, params and state_steps must be CUDA tensors."
#     254 else:
# --> 255     assert not step_t.is_cuda, "If capturable=False, state_steps should not be CUDA tensors."
#     257 # update step
#     258 step_t += 1
#
# AssertionError: If capturable=False, state_steps should not be CUDA tensors.

# %% [markdown]
# ### 4.Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model,env,n_eval_episodes=10, render =True)
# Out:
# D:\Program_Installation\anaconda\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# ### 5.Test Model

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs)
        n_state, reward, done, info = env.step(action)
        score += reward
    print(f'Episode: {episode} score: {score}')
env.close()
# Out:
# Episode: 1 score: [29.]
# Episode: 2 score: [31.]
# Episode: 3 score: [16.]
# Episode: 4 score: [13.]
# Episode: 5 score: [18.]

# %%
env.reset()
# Out:
# array([[-0.04757111,  0.02003796, -0.04715839,  0.01410156]],
#       dtype=float32)

# %% [markdown]
# ### 6. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path,'PPO_1')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_1'

# %%
# !tensorboard --logdir = {training_log_path}
# Out:
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
#                    [--samples_per_plugin SAMPLES_PER_PLUGIN]
#                    [--detect_file_replacement BOOL]
#                    [--whatif-use-unsafe-custom-prediction YOUR_CUSTOM_PREDICT_FUNCTION.py]
#                    [--whatif-data-dir PATH]
#                    {serve,dev} ...
# tensorboard: error: argument {serve,dev}: invalid choice: 'Training\\Logs\\PPO_1' (choose from 'serve', 'dev')

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 62FE-D118
#
#  Directory of C:\Users\Awesome\Downloads\ATT blog\Open AI Gym\baseline
#
# 17-Jul-22  12:10 AM    <DIR>          .
# 17-Jul-22  12:10 AM    <DIR>          ..
# 14-Jul-22  08:20 AM    <DIR>          .ipynb_checkpoints
# 17-Jul-22  12:10 AM            50,820 baseline_rl.ipynb
# 16-Jul-22  10:43 PM    <DIR>          Training
#                1 File(s)         50,820 bytes
#                4 Dir(s)  315,797,667,840 bytes free

# %% [markdown]
# ### 8. Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training','Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                            callback_on_new_best = stop_callback,
                            eval_freq=10000,
                            best_model_save_path=save_path,
                            verbose=1)

# %%
model = PPO('MlpPolicy',env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    fps             | 47       |
# |    iterations      | 1        |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 27.1        |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 2           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008520352 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00147    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 47.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.2        |
# |    ep_rew_mean          | 34.2        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 3           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008210663 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0659      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 38.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.5        |
# |    ep_rew_mean          | 46.5        |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 4           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008259101 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 52.8        |
# -----------------------------------------
# D:\Program_Installation\anaconda\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007378431 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 61.4        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# ### 9. Changing Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %% [markdown]
# #### Define new neural network

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log = log_path,policy_kwargs={'net_arch':net_arch})
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    fps             | 428      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015458845 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.000876   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.3        |
# |    ep_rew_mean          | 43.3        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015078833 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.032      |
# |    value_loss           | 28.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.1       |
# |    ep_rew_mean          | 59.1       |
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 4          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01016967 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.601     |
# |    explained_variance   | 0.403      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.3       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0255    |
# |    value_loss           | 48.8       |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.013935151 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 45.5        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     |